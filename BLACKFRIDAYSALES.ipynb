# %% [markdown]
# ##### CHIRAG BLACK FRIDAY SALES PROJECT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
traindata = pd.read_csv(r"train.csv")

# %%
traindata.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
    traindata.tail()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 550063                          1               1                  20
# 550064                          3               0                  20
# 550065                         4+               1                  20
# 550066                          2               0                  20
# 550067                         4+               1                  20
#
#         Product_Category_2  Product_Category_3  Purchase
# 550063                 NaN                 NaN       368
# ...

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
traindata.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
traindata.shape
# Out:
# (550068, 12)

# %%
traindata['User_ID'].reset_index()
# Out:
#          index  User_ID
# 0            0  1000001
# 1            1  1000001
# 2            2  1000001
# 3            3  1000001
# 4            4  1000002
# ...        ...      ...
# 550063  550063  1006033
# 550064  550064  1006035
# 550065  550065  1006036
# 550066  550066  1006038
# 550067  550067  1006039
#
# [550068 rows x 2 columns]

# %%
traindata['Product_ID'].reset_index()
# Out:
#          index Product_ID
# 0            0  P00069042
# 1            1  P00248942
# 2            2  P00087842
# 3            3  P00085442
# 4            4  P00285442
# ...        ...        ...
# 550063  550063  P00372445
# 550064  550064  P00375436
# 550065  550065  P00375436
# 550066  550066  P00375436
# 550067  550067  P00371644
#
# [550068 rows x 2 columns]

# %%
traindata['Gender'].reset_index()
# Out:
#          index Gender
# 0            0      F
# 1            1      F
# 2            2      F
# 3            3      F
# 4            4      M
# ...        ...    ...
# 550063  550063      M
# 550064  550064      F
# 550065  550065      F
# 550066  550066      F
# 550067  550067      F
#
# [550068 rows x 2 columns]

# %%
traindata['Age'].reset_index()
# Out:
#          index    Age
# 0            0   0-17
# 1            1   0-17
# 2            2   0-17
# 3            3   0-17
# 4            4    55+
# ...        ...    ...
# 550063  550063  51-55
# 550064  550064  26-35
# 550065  550065  26-35
# 550066  550066    55+
# 550067  550067  46-50
#
# [550068 rows x 2 columns]

# %%
traindata['Occupation'].reset_index()
# Out:
#          index  Occupation
# 0            0          10
# 1            1          10
# 2            2          10
# 3            3          10
# 4            4          16
# ...        ...         ...
# 550063  550063          13
# 550064  550064           1
# 550065  550065          15
# 550066  550066           1
# 550067  550067           0
#
# [550068 rows x 2 columns]

# %%
traindata['City_Category'].reset_index()
# Out:
#          index City_Category
# 0            0             A
# 1            1             A
# 2            2             A
# 3            3             A
# 4            4             C
# ...        ...           ...
# 550063  550063             B
# 550064  550064             C
# 550065  550065             B
# 550066  550066             C
# 550067  550067             B
#
# [550068 rows x 2 columns]

# %%
traindata['Stay_In_Current_City_Years'].reset_index()
# Out:
#          index Stay_In_Current_City_Years
# 0            0                          2
# 1            1                          2
# 2            2                          2
# 3            3                          2
# 4            4                         4+
# ...        ...                        ...
# 550063  550063                          1
# 550064  550064                          3
# 550065  550065                         4+
# 550066  550066                          2
# 550067  550067                         4+
#
# [550068 rows x 2 columns]

# %%
traindata['Marital_Status'].reset_index()
# Out:
#          index  Marital_Status
# 0            0               0
# 1            1               0
# 2            2               0
# 3            3               0
# 4            4               0
# ...        ...             ...
# 550063  550063               1
# 550064  550064               0
# 550065  550065               1
# 550066  550066               0
# 550067  550067               1
#
# [550068 rows x 2 columns]

# %%
traindata['Product_Category_1'].reset_index()
# Out:
#          index  Product_Category_1
# 0            0                   3
# 1            1                   1
# 2            2                  12
# 3            3                  12
# 4            4                   8
# ...        ...                 ...
# 550063  550063                  20
# 550064  550064                  20
# 550065  550065                  20
# 550066  550066                  20
# 550067  550067                  20
#
# [550068 rows x 2 columns]

# %%
traindata['Product_Category_2'].reset_index()
# Out:
#          index  Product_Category_2
# 0            0                 NaN
# 1            1                 6.0
# 2            2                 NaN
# 3            3                14.0
# 4            4                 NaN
# ...        ...                 ...
# 550063  550063                 NaN
# 550064  550064                 NaN
# 550065  550065                 NaN
# 550066  550066                 NaN
# 550067  550067                 NaN
#
# [550068 rows x 2 columns]

# %%
traindata['Product_Category_3'].reset_index()
# Out:
#          index  Product_Category_3
# 0            0                 NaN
# 1            1                14.0
# 2            2                 NaN
# 3            3                 NaN
# 4            4                 NaN
# ...        ...                 ...
# 550063  550063                 NaN
# 550064  550064                 NaN
# 550065  550065                 NaN
# 550066  550066                 NaN
# 550067  550067                 NaN
#
# [550068 rows x 2 columns]

# %%
traindata['Purchase'].reset_index()
# Out:
#          index  Purchase
# 0            0      8370
# 1            1     15200
# 2            2      1422
# 3            3      1057
# 4            4      7969
# ...        ...       ...
# 550063  550063       368
# 550064  550064       371
# 550065  550065       137
# 550066  550066       365
# 550067  550067       490
#
# [550068 rows x 2 columns]

# %%
x = traindata['Marital_Status'].head(30)
y = traindata['Purchase'].head(30)
plt.scatter(x,y)
plt.title("Marital_Status Wise Data Purchase")
plt.xlabel("Marital_Status")
plt.ylabel("Purchase")
plt.show()

# %%
x = traindata['Purchase'].head(200)
plt.hist(x)
plt.show()

# %%
traindata['Gender']=traindata['Gender'].map({'F':0,'M':1})

# %%
traindata.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
traindata['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
traindata['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
traindata['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
traindata['Product_Category_2'].value_counts().reset_index()
# Out:
#     Product_Category_2  count
# 0                  8.0  64088
# 1                 14.0  55108
# 2                  2.0  49217
# 3                 16.0  43255
# 4                 15.0  37855
# 5                  5.0  26235
# 6                  4.0  25677
# 7                  6.0  16466
# 8                 11.0  14134
# 9                 17.0  13320
# 10                13.0  10531
# 11                 9.0   5693
# 12                12.0   5528
# 13                10.0   3043
# 14                 3.0   2884
# 15                18.0   2770
# 16                 7.0    626

# %%
plt.bar(traindata['Product_Category_1'].unique(),traindata['Product_Category_1'].value_counts())
# Out:
# <BarContainer object of 20 artists>

# %%
traindata['Product_Category_2'].mode()
# Out:
# 0    8.0
# Name: Product_Category_2, dtype: float64

# %%
traindata['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
traindata['Product_Category_2']=traindata['Product_Category_2'].fillna(traindata['Product_Category_2'].mode()[0])

# %%
traindata['Product_Category_2'].isnull().sum()
# Out:
# 0

# %%
traindata['Product_Category_3'].unique()
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
traindata['Product_Category_3'].value_counts().reset_index()
# Out:
#     Product_Category_3  count
# 0                 16.0  32636
# 1                 15.0  28013
# 2                 14.0  18428
# 3                 17.0  16702
# 4                  5.0  16658
# 5                  8.0  12562
# 6                  9.0  11579
# 7                 12.0   9246
# 8                 13.0   5459
# 9                  6.0   4890
# 10                18.0   4629
# 11                 4.0   1875
# 12                11.0   1805
# 13                10.0   1726
# 14                 3.0    613

# %%
traindata['Product_Category_3'].mode()[0]
# Out:
# 16.0

# %%
traindata['Product_Category_3']=traindata['Product_Category_3'].fillna(traindata['Product_Category_3'].mode()[0])

# %%
traindata['Product_Category_3'].isnull().sum()
# Out:
# 0

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  int64
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          550068 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# ...

# %%
traindata.shape
# Out:
# (550068, 12)

# %%
traindata.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
traindata.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
traindata.shape
# Out:
# (550068, 12)

# %%
traindata['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
traindata['Stay_In_Current_City_Years']=traindata['Stay_In_Current_City_Years'].str.replace('+','')

# %%
traindata.head()
# Out:
#    User_ID Product_ID  Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042       0  0-17          10             A
# 1  1000001  P00248942       0  0-17          10             A
# 2  1000001  P00087842       0  0-17          10             A
# 3  1000001  P00085442       0  0-17          10             A
# 4  1000002  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                          4               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 8.0                16.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  int64
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          550068 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# ...

# %%
traindata['Stay_In_Current_City_Years']=traindata['Stay_In_Current_City_Years'].astype(int)

# %%
traindata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  int64
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  int32
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          550068 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int32(1), int64(6), object(3)
# ...
